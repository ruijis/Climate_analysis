# %%
import pandas as pd
df = pd.read_csv('baseline_cooling_design.csv')

# %%
df
# Out:
#                    Building  Block   Zone  Design Capacity (kW)  \
# Building 1 Block 1   Zone 1   6.14  0.333                  5.34
#            -         Totals   6.14  0.333                  5.34
#
#                     Design Flow Rate (m3/s)  Total Cooling Load (kW)  \
# Building 1 Block 1                      4.9                     0.44
#            -                            4.9                     0.44
#
#                     Sensible (kW)  Latent (kW) Air Temperature (�C)  \
# Building 1 Block 1           26.0         43.6            Jul 17:00
#            -                 26.0         43.6                  NaN
#
#                     Humidity (%)  ...  Roof and Ceiling Gains (kW)  \
# Building 1 Block 1         33.11  ...                         0.08
#            -               33.11  ...                         0.08
#
#                     Ventilation Gains (kW)  Infiltration Gains (kW)  \
# Building 1 Block 1                    0.49                     0.57
# ...
